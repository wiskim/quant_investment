# %%
pf.create_returns_tear_sheet(port_ret_df['port_ret'])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2003-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-06-11</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>199</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>14.292%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>822.775%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>19.739%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.78</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.24</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.86</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-59.406%</td>
#     </tr>
#     <tr>
# ...

# %%
stock_ret_df.loc[~stock_ret_df['2020-06-11'].isna(), ['stock_cd', 'stock_nm','2020-06-11']]
# Out:
#     stock_cd stock_nm  2020-06-11
# 12   A016090       대현   -0.279208
# 145  A020000       한섬   -0.044017
# 203  A018310    삼목에스폼   -0.351020
# 205  A039010     현대통신   -0.320398
# 208  A042700    한미반도체    0.134228
# 238  A109080     옵티시스    0.093750
# 241  A028100     동아지질   -0.427273
# 254  A001820    삼화콘덴서    0.097701
# 255  A002170     삼양통상   -0.176647
# 256  A004000   롯데정밀화학   -0.293785
# 257  A006580     대양제지   -0.320930
# 258  A006740     영풍제지   -0.037901
# 259  A016590    신대양제지   -0.297531
# 260  A045300    성우테크론   -0.021489
# 261  A086390    유니테스트    0.140496
# 262  A094280    효성ITX    1.000000
# 263  A094970     제이엠티    0.037037
# 264  A130580   나이스디앤비    0.197183
# 265  A141000     비아트론   -0.162667
# 266  A192440   슈피겐코리아    0.122417

# %%
stock_ret_df.loc[~stock_ret_df['2019-06-28'].isna(), ['stock_cd', 'stock_nm','2019-06-28']]
# Out:
#     stock_cd stock_nm  2019-06-28
# 46   A011170    롯데케미칼   -0.234848
# 81   A013120     동원개발    0.334197
# 163  A056190   에스에프에이    0.249226
# 170  A005710     대원산업   -0.081042
# 199  A108230       톱텍   -0.608017
# 232  A011370       서한   -0.166667
# 240  A000660   SK하이닉스   -0.169654
# 241  A028100     동아지질    0.512195
# 242  A035200    프럼파스트   -0.243407
# 243  A037440       희림   -0.053741
# 244  A066670   디스플레이텍    0.019685
# 245  A069260      휴켐스   -0.254237
# 246  A078150  HB테크놀러지    0.553812
# 247  A083310    엘오티베큠   -0.290456
# 248  A092070     디엔에프   -0.383710
# 249  A093520      매커스   -0.160808
# 250  A115310     인포바인   -0.032538
# 251  A119860      다나와    0.629393
# 252  A149950      아바텍    0.336120
# 253  A208140      정다운    0.023769

# %%
date = stock_ret_df.columns[stock_ret_df.columns.str.startswith('2019')][0]
stock_ret_df.loc[~stock_ret_df[date].isna(), ['stock_cd', 'stock_nm', date]]
# Out:
#     stock_cd stock_nm  2019-06-28
# 46   A011170    롯데케미칼   -0.234848
# 81   A013120     동원개발    0.334197
# 163  A056190   에스에프에이    0.249226
# 170  A005710     대원산업   -0.081042
# 199  A108230       톱텍   -0.608017
# 232  A011370       서한   -0.166667
# 240  A000660   SK하이닉스   -0.169654
# 241  A028100     동아지질    0.512195
# 242  A035200    프럼파스트   -0.243407
# 243  A037440       희림   -0.053741
# 244  A066670   디스플레이텍    0.019685
# 245  A069260      휴켐스   -0.254237
# 246  A078150  HB테크놀러지    0.553812
# 247  A083310    엘오티베큠   -0.290456
# 248  A092070     디엔에프   -0.383710
# 249  A093520      매커스   -0.160808
# 250  A115310     인포바인   -0.032538
# 251  A119860      다나와    0.629393
# 252  A149950      아바텍    0.336120
# 253  A208140      정다운    0.023769

# %%
date = stock_ret_df.columns[stock_ret_df.columns.str.startswith('2018')][0]
stock_ret_df.loc[~stock_ret_df[date].isna(), ['stock_cd', 'stock_nm', date]]
# Out:
#     stock_cd stock_nm  2018-06-29
# 12   A016090       대현   -0.152350
# 28   A007700      F&F    2.044776
# 30   A011040     경동제약    0.281647
# 50   A023150    MH에탄올   -0.308913
# 69   A033130    디지틀조선   -0.107456
# 102  A036190   금화피에스시   -0.030471
# 115  A028150    GS홈쇼핑   -0.223565
# 181  A064480     브리지텍   -0.492647
# 189  A036800  나이스정보통신   -0.058052
# 229  A161000     애경유화   -0.282540
# 230  A005500     삼진제약    0.368182
# 231  A009300     삼아제약   -0.053571
# 232  A011370       서한   -0.213333
# 233  A036010    아비코전자    0.207701
# 234  A058430    포스코강판   -0.509918
# 235  A067280    멀티캠퍼스   -0.045946
# 236  A084370     유진테크   -0.110169
# 237  A086280   현대글로비스   -0.268987
# 238  A109080     옵티시스    0.026049
# 239  A147830     제룡산업   -0.027660

# %%
date = stock_ret_df.columns[stock_ret_df.columns.str.startswith('2017')][0]
stock_ret_df.loc[~stock_ret_df[date].isna(), ['stock_cd', 'stock_nm', date]]
# Out:
#     stock_cd   stock_nm  2017-06-30
# 46   A011170      롯데케미칼    0.204904
# 50   A023150      MH에탄올    0.105263
# 77   A006650       대한유화    0.060797
# 103  A039340     한국경제TV   -0.270690
# 114  A023890  한국아트라스비엑스    0.007407
# 200  A120030       조선선재    0.300485
# 216  A004780       대륙제관    0.044118
# 217  A008370         원풍   -0.045407
# 218  A012630        HDC    0.202308
# 219  A023910       대한약품    0.156040
# 220  A036480      대성미생물   -0.164415
# 221  A043200         파루   -0.141414
# 222  A049720     고려신용정보    0.195266
# 223  A053210     스카이라이프   -0.003049
# 224  A054040      한국컴퓨터    0.644315
# 225  A078070    유비쿼스홀딩스   -0.022898
# 226  A081000      일진다이아    0.061341
# 227  A084010       대한제강    0.574618
# 228  A100220       비상교육    0.244541
# 229  A161000       애경유화    0.638831

# %%
date = stock_ret_df.columns[stock_ret_df.columns.str.startswith('2016')][0]
stock_ret_df.loc[~stock_ret_df[date].isna(), ['stock_cd', 'stock_nm', date]]
# Out:
#     stock_cd stock_nm  2016-06-30
# 81   A013120     동원개발   -0.217469
# 117  A035250     강원랜드    0.094488
# 138  A084670     동양고속   -0.015571
# 193  A067830  세이브존I&C   -0.130856
# 194  A081580     성우전자    0.225734
# 201  A002360  SH에너지화학   -0.028571
# 202  A004450     삼화왕관   -0.111675
# 203  A018310    삼목에스폼   -0.320712
# 204  A037330   인지디스플레    0.138462
# 205  A039010     현대통신   -0.112245
# 206  A041460   한국전자인증    0.866667
# 207  A042110     에스씨디   -0.212679
# 208  A042700    한미반도체    0.010830
# 209  A056360      코위버   -0.104730
# 210  A060370   KT서브마린    0.174089
# 211  A069540     라이트론    0.157197
# 212  A075180  새론오토모티브   -0.187243
# 213  A089140      넥스턴    0.646278
# 214  A101330     모베이스   -0.046207
# 215  A123860     아나패스   -0.040441

# %%
date = stock_ret_df.columns[stock_ret_df.columns.str.startswith('2015')][0]
stock_ret_df.loc[~stock_ret_df[date].isna(), ['stock_cd', 'stock_nm', date]]
# Out:
#     stock_cd stock_nm  2015-06-30
# 30   A011040     경동제약    0.315825
# 74   A069620     대웅제약    1.185886
# 135  A063570   한국전자금융    0.240557
# 184  A004380    삼익THK    0.025704
# 185  A007590    동방아그로    0.378834
# 186  A013030   하이록코리아    0.155224
# 187  A015020     이스타코   -0.324921
# 188  A032960     동일기연    0.420730
# 189  A036800  나이스정보통신    0.711735
# 190  A041930     동아화성   -0.013846
# 191  A053740   국제엘렉트릭    0.315789
# 192  A067010     이씨에스    0.153333
# 193  A067830  세이브존I&C   -0.045872
# 194  A081580     성우전자   -0.130952
# 195  A090740   연이정보통신   -0.118919
# 196  A093190      빅솔론    0.202739
# 197  A095660     네오위즈    0.124638
# 198  A100030    모바일리더   -0.056604
# 199  A108230       톱텍    0.396836
# 200  A120030     조선선재    0.195266

# %%
date = stock_ret_df.columns[stock_ret_df.columns.str.startswith('2014')][0]
stock_ret_df.loc[~stock_ret_df[date].isna(), ['stock_cd', 'stock_nm', date]]
# Out:
#     stock_cd    stock_nm  2014-06-30
# 55   A036830        솔브레인   -0.222973
# 85   A027390  한화갤러리아타임월드   -0.124825
# 110  A004490        세방전지   -0.145946
# 114  A023890   한국아트라스비엑스    0.023780
# 158  A015230        대창단조    0.026257
# 169  A002200        수출포장   -0.267035
# 170  A005710        대원산업    0.485861
# 171  A008060        대덕전자   -0.134845
# 172  A012690        모나리자   -0.172775
# 173  A017650        대림제지    0.249631
# 174  A031330      에스에이엠티    0.068269
# 175  A032750          삼진   -0.104603
# 176  A036690         코맥스    0.481101
# 177  A039440       에스티아이    1.282844
# 178  A049830          승일    0.923567
# 179  A052460      아이크래프트   -0.041803
# 180  A053160        프리엠스   -0.081794
# 181  A064480        브리지텍    0.197785
# 182  A074130        디아이디   -0.462963
# 183  A078520      에이블씨엔씨   -0.371880

# %%
date = stock_ret_df.columns[stock_ret_df.columns.str.startswith('2013')][0]
stock_ret_df.loc[~stock_ret_df[date].isna(), ['stock_cd', 'stock_nm', date]]
# Out:
#     stock_cd    stock_nm  2013-06-28
# 61   A003670      포스코케미칼   -0.119087
# 85   A027390  한화갤러리아타임월드    0.896277
# 132  A037710       광주신세계    0.298544
# 136  A064420      케이피케미칼   -0.090226
# 147  A053610         프로텍    0.152355
# 154  A001420        태원물산   -0.279113
# 155  A003780        진양산업    0.124402
# 156  A006380         카프로   -0.606509
# 157  A009770        삼정펄프    0.903409
# 158  A015230        대창단조    0.262468
# 159  A029530        신도리코    0.043478
# 160  A032040     C&S자산관리    0.735515
# 161  A033540         파라텍   -0.094538
# 162  A054540        삼영엠텍    0.465181
# 163  A056190      에스에프에이    0.059041
# 164  A066620       국보디자인    0.451613
# 165  A069330        유아이디    0.875728
# 166  A069410         엔텔스    1.463876
# 167  A097870       효성오앤비   -0.027654
# 168  A098120     마이크로컨텍솔    0.280728

# %%
date = stock_ret_df.columns[stock_ret_df.columns.str.startswith('2012')][0]
stock_ret_df.loc[~stock_ret_df[date].isna(), ['stock_cd', 'stock_nm', date]]
# Out:
#     stock_cd    stock_nm  2012-06-29
# 21   A002250      알보젠코리아   -0.077982
# 28   A007700         F&F   -0.365755
# 82   A016510       현대DSF    0.000000
# 85   A027390  한화갤러리아타임월드   -0.183807
# 87   A052600         한네트   -0.145455
# 132  A037710       광주신세계    0.128767
# 140  A000250       삼천당제약   -0.173228
# 141  A003100          선광    0.077170
# 142  A004890        동일산업   -0.316282
# 143  A006370       대구백화점    0.165957
# 144  A014130      한익스프레스   -0.277207
# 145  A020000          한섬   -0.039326
# 146  A040420     정상제이엘에스   -0.276596
# 147  A053610         프로텍    0.159741
# 148  A066130          하츠    0.795122
# 149  A069510         에스텍   -0.204348
# 150  A073190         듀오백    0.048622
# 151  A091970        나노캠텍   -0.236170
# 152  A092460       한라IMS    0.559574
# 153  A095270     웨이브일렉트로   -0.358333

# %%
date = stock_ret_df.columns[stock_ret_df.columns.str.startswith('2011')][0]
stock_ret_df.loc[~stock_ret_df[date].isna(), ['stock_cd', 'stock_nm', date]]
# Out:
#     stock_cd  stock_nm  2011-06-30
# 23   A003800     에이스침대    0.494983
# 53   A030960       양지사    0.823529
# 74   A069620      대웅제약   -0.136522
# 120  A051390        YW   -0.405983
# 124  A001080      만호제강    0.033435
# 125  A002300      한국제지   -0.489914
# 126  A002350     넥센타이어    1.580000
# 127  A002620   제일파마홀딩스   -0.068974
# 128  A003230      삼양식품    0.595376
# 129  A006890      태경화학   -0.374010
# 130  A023960  에쓰씨엔지니어링   -0.356818
# 131  A028080    휴맥스홀딩스   -0.267901
# 132  A037710     광주신세계    0.199346
# 133  A053260      금강철강    0.107226
# 134  A060720      KH바텍   -0.303908
# 135  A063570    한국전자금융   -0.194492
# 136  A064420    케이피케미칼    1.125541
# 137  A065680    우주일렉트로   -0.184307
# 138  A084670      동양고속   -0.280675
# 139  A088910   동우팜투테이블    0.146949

# %%
date = stock_ret_df.columns[stock_ret_df.columns.str.startswith('2010')][0]
stock_ret_df.loc[~stock_ret_df[date].isna(), ['stock_cd', 'stock_nm', date]]
# Out:
#     stock_cd   stock_nm  2010-06-30
# 34   A016800        퍼시스    0.419326
# 79   A010130       고려아연    0.591241
# 87   A052600        한네트    0.277916
# 102  A036190     금화피에스시    0.017621
# 108  A072130        유엔젤   -0.328297
# 109  A078000       텔코웨어   -0.006766
# 110  A004490       세방전지    0.089888
# 111  A004970       신라교역   -0.094474
# 112  A014620       성광벤드    0.030769
# 113  A017960       한국카본   -0.285360
# 114  A023890  한국아트라스비엑스    0.227811
# 115  A028150      GS홈쇼핑    0.188563
# 116  A033200        모아텍   -0.061257
# 117  A035250       강원랜드    0.114458
# 118  A037630       에스비엠   -0.010101
# 119  A048470       대동스틸   -0.107744
# 120  A051390         YW    0.425993
# 121  A058450         일야   -0.400877
# 122  A069730      DSR제강   -0.306140
# 123  A079000     와토스코리아   -0.156632
